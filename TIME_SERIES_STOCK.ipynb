# %% [markdown]
# <a href="https://colab.research.google.com/github/anjanamathew93/stockprice_forecastmodel/blob/main/TIME_SERIES_STOCK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.statespace.sarimax import SARIMAX
import yfinance as yf
import os

# Define the companies and the period
companies = ['AAPL', 'AMZN', 'GOOGL', 'META', 'NFLX', 'MSFT']
start_date = '2024-07-30'
end_date = '2024-12-31'  # Extend end date to include December

# Download stock data and forecast for each company
forecast_steps = 62  # Forecasting for 62 days (from Dec 1 to Jan 31)

for company in companies:
    # Download stock data
    stock = yf.Ticker(company)
    stock_data = stock.history(start=start_date, end=end_date)

    # Prepare the data
    stock_data = stock_data[['Close']].copy()
    stock_data.columns = ['Stock Price']

    # Save to CSV
    csv_file_path = f'/content/{company}_stock_data_q3_q4_2024.csv'
    stock_data.to_csv(csv_file_path, index=True)

    print(f"Stock data for {company} has been exported to {csv_file_path}")

    # Decomposing the time series
    result = seasonal_decompose(stock_data['Stock Price'], model='additive', period=30)
    result.plot()
    plt.show()

    # Checking for stationarity
    from statsmodels.tsa.stattools import adfuller

    result = adfuller(stock_data['Stock Price'])
    print(f'{company} - ADF Statistic: %f' % result[0])
    print(f'{company} - p-value: %f' % result[1])

    # If non-stationary, perform differencing
    if result[1] > 0.05:
        stock_data['Stock Price'] = stock_data['Stock Price'].diff().dropna()
        # No further decomposition on differenced data

    # Forecasting using SARIMA
    model = SARIMAX(stock_data['Stock Price'], order=(5, 1, 0), seasonal_order=(1, 1, 1, 12))
    model_fit = model.fit(disp=False)
    print(model_fit.summary())

    # Making future predictions
    forecast = model_fit.get_forecast(steps=forecast_steps)

    # Extract the forecast mean and confidence intervals
    forecast_mean = forecast.predicted_mean
    forecast_conf_int = forecast.conf_int()
    forecast_index = pd.date_range(start='2024-12-01', periods=forecast_steps, freq='D')

    # Plotting the forecast along with actual data
    plt.figure(figsize=(12, 8))
    plt.plot(stock_data.index, stock_data['Stock Price'], label='Historical')
    plt.plot(forecast_index, forecast_mean, label='Forecast')
    plt.fill_between(forecast_index, forecast_conf_int.iloc[:, 0], forecast_conf_int.iloc[:, 1], color='gray', alpha=0.3)
    plt.axvline(pd.Timestamp('2024-12-01'), color='red', linestyle='--', label='Start of Forecast')
    plt.title(f'{company} Stock Price Forecast for December and January')
    plt.xlabel('Date')
    plt.ylabel('Stock Price')
    plt.legend()
    plt.show()
# Out:
# Stock data for AAPL has been exported to /content/AAPL_stock_data_q3_q4_2024.csv
# AAPL - ADF Statistic: -0.774021
# AAPL - p-value: 0.826634
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                          Stock Price   No. Observations:                  107
# Model:             SARIMAX(5, 1, 0)x(1, 1, [1], 12)   Log Likelihood                -257.557
# Date:                              Thu, 30 Jan 2025   AIC                            531.114
# Time:                                      08:52:52   BIC                            551.461
# Sample:                                           0   HQIC                           539.333
#                                               - 107
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.7412      0.109     -6.774      0.000      -0.956      -0.527
# ar.L2         -0.6525      0.151     -4.331      0.000      -0.948      -0.357
# ar.L3         -0.6733      0.153     -4.408      0.000      -0.973      -0.374
# ar.L4         -0.3087      0.163     -1.895      0.058      -0.628       0.011
# ar.L5         -0.2929      0.117     -2.511      0.012      -0.521      -0.064
# ar.S.L12      -0.0799      0.192     -0.416      0.678      -0.457       0.297
# ma.S.L12      -0.6916      0.231     -2.990      0.003      -1.145      -0.238
# sigma2        11.3649      1.976      5.751      0.000       7.492      15.238
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.43   Jarque-Bera (JB):                 1.03
# Prob(Q):                              0.51   Prob(JB):                         0.60
# Heteroskedasticity (H):               0.54   Skew:                             0.25
# Prob(H) (two-sided):                  0.09   Kurtosis:                         3.12
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# Stock data for AMZN has been exported to /content/AMZN_stock_data_q3_q4_2024.csv
# AMZN - ADF Statistic: -0.653779
# AMZN - p-value: 0.858361
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                          Stock Price   No. Observations:                  107
# Model:             SARIMAX(5, 1, 0)x(1, 1, [1], 12)   Log Likelihood                -281.355
# Date:                              Thu, 30 Jan 2025   AIC                            578.709
# Time:                                      08:52:55   BIC                            599.056
# Sample:                                           0   HQIC                           586.928
#                                               - 107
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.7929      0.092     -8.635      0.000      -0.973      -0.613
# ar.L2         -0.7638      0.120     -6.344      0.000      -1.000      -0.528
# ar.L3         -0.6658      0.134     -4.982      0.000      -0.928      -0.404
# ar.L4         -0.4612      0.158     -2.911      0.004      -0.772      -0.151
# ar.L5         -0.2978      0.127     -2.344      0.019      -0.547      -0.049
# ar.S.L12      -0.2373      0.179     -1.329      0.184      -0.587       0.113
# ma.S.L12      -0.9974     10.839     -0.092      0.927     -22.241      20.246
# sigma2        14.9937    161.880      0.093      0.926    -302.284     332.272
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.06   Jarque-Bera (JB):                 2.33
# Prob(Q):                              0.81   Prob(JB):                         0.31
# Heteroskedasticity (H):               0.91   Skew:                             0.24
# Prob(H) (two-sided):                  0.79   Kurtosis:                         2.39
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# Stock data for GOOGL has been exported to /content/GOOGL_stock_data_q3_q4_2024.csv
# GOOGL - ADF Statistic: -0.528425
# GOOGL - p-value: 0.886349
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                          Stock Price   No. Observations:                  107
# Model:             SARIMAX(5, 1, 0)x(1, 1, [1], 12)   Log Likelihood                -247.678
# Date:                              Thu, 30 Jan 2025   AIC                            511.357
# Time:                                      08:52:57   BIC                            531.703
# Sample:                                           0   HQIC                           519.575
#                                               - 107
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.5154      0.099     -5.215      0.000      -0.709      -0.322
# ar.L2         -0.6232      0.098     -6.369      0.000      -0.815      -0.431
# ar.L3         -0.5421      0.125     -4.351      0.000      -0.786      -0.298
# ar.L4         -0.2842      0.106     -2.674      0.007      -0.492      -0.076
# ar.L5         -0.2367      0.127     -1.869      0.062      -0.485       0.011
# ar.S.L12      -0.4629      0.136     -3.411      0.001      -0.729      -0.197
# ma.S.L12      -0.9015      0.393     -2.293      0.022      -1.672      -0.131
# sigma2         7.4523      2.433      3.063      0.002       2.684      12.221
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.15   Jarque-Bera (JB):                 2.42
# Prob(Q):                              0.70   Prob(JB):                         0.30
# Heteroskedasticity (H):               1.94   Skew:                            -0.36
# Prob(H) (two-sided):                  0.07   Kurtosis:                         3.30
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# Stock data for META has been exported to /content/META_stock_data_q3_q4_2024.csv
# META - ADF Statistic: -2.465067
# META - p-value: 0.124207
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                          Stock Price   No. Observations:                  107
# Model:             SARIMAX(5, 1, 0)x(1, 1, [1], 12)   Log Likelihood                -362.952
# Date:                              Thu, 30 Jan 2025   AIC                            741.904
# Time:                                      08:52:59   BIC                            762.251
# Sample:                                           0   HQIC                           750.123
#                                               - 107
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.8610      0.125     -6.886      0.000      -1.106      -0.616
# ar.L2         -0.7489      0.152     -4.915      0.000      -1.048      -0.450
# ar.L3         -0.5837      0.154     -3.793      0.000      -0.885      -0.282
# ar.L4         -0.4876      0.143     -3.414      0.001      -0.768      -0.208
# ar.L5         -0.2286      0.106     -2.152      0.031      -0.437      -0.020
# ar.S.L12      -0.3468      0.155     -2.238      0.025      -0.650      -0.043
# ma.S.L12      -0.6994      0.136     -5.131      0.000      -0.967      -0.432
# sigma2       103.0479     15.945      6.463      0.000      71.796     134.299
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.17   Jarque-Bera (JB):                 0.00
# Prob(Q):                              0.68   Prob(JB):                         1.00
# Heteroskedasticity (H):               1.66   Skew:                             0.01
# Prob(H) (two-sided):                  0.16   Kurtosis:                         2.97
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# Stock data for NFLX has been exported to /content/NFLX_stock_data_q3_q4_2024.csv
# NFLX - ADF Statistic: -0.695621
# NFLX - p-value: 0.847881
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                          Stock Price   No. Observations:                  107
# Model:             SARIMAX(5, 1, 0)x(1, 1, [1], 12)   Log Likelihood                -400.681
# Date:                              Thu, 30 Jan 2025   AIC                            817.361
# Time:                                      08:53:01   BIC                            837.708
# Sample:                                           0   HQIC                           825.580
#                                               - 107
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.8306      0.124     -6.699      0.000      -1.074      -0.588
# ar.L2         -0.6521      0.137     -4.754      0.000      -0.921      -0.383
# ar.L3         -0.5030      0.169     -2.980      0.003      -0.834      -0.172
# ar.L4         -0.4063      0.195     -2.089      0.037      -0.788      -0.025
# ar.L5         -0.3215      0.092     -3.510      0.000      -0.501      -0.142
# ar.S.L12      -0.0547      0.165     -0.332      0.740      -0.377       0.268
# ma.S.L12      -0.9990     49.318     -0.020      0.984     -97.660      95.662
# sigma2       204.2727   1.01e+04      0.020      0.984   -1.95e+04    1.99e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.73   Jarque-Bera (JB):               274.13
# Prob(Q):                              0.39   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.83   Skew:                             1.47
# Prob(H) (two-sided):                  0.10   Kurtosis:                        10.84
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Stock data for MSFT has been exported to /content/MSFT_stock_data_q3_q4_2024.csv
# MSFT - ADF Statistic: -2.258495
# MSFT - p-value: 0.185704
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                          Stock Price   No. Observations:                  107
# Model:             SARIMAX(5, 1, 0)x(1, 1, [1], 12)   Log Likelihood                -315.853
# Date:                              Thu, 30 Jan 2025   AIC                            647.705
# Time:                                      08:53:07   BIC                            668.052
# Sample:                                           0   HQIC                           655.924
#                                               - 107
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.7823      0.133     -5.895      0.000      -1.042      -0.522
# ar.L2         -0.6331      0.165     -3.832      0.000      -0.957      -0.309
# ar.L3         -0.4517      0.190     -2.380      0.017      -0.824      -0.080
# ar.L4         -0.3780      0.187     -2.022      0.043      -0.745      -0.012
# ar.L5         -0.2636      0.151     -1.750      0.080      -0.559       0.032
# ar.S.L12      -0.1499      0.204     -0.736      0.462      -0.549       0.249
# ma.S.L12      -0.9996    117.360     -0.009      0.993    -231.020     229.021
# sigma2        32.2104   3775.054      0.009      0.993   -7366.759    7431.180
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.17   Jarque-Bera (JB):                78.07
# Prob(Q):                              0.68   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.06   Skew:                            -1.25
# Prob(H) (two-sided):                  0.86   Kurtosis:                         6.69
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.11/dist-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
